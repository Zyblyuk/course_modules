# %% [markdown]
# ## Предсказание ухода клиента в телекоммуникационной компании
#
# #### Описание:
#
# Вы работаете с набором данных о клиентах телекоммуникационной компании. Ваша задача — построить модель машинного обучения для предсказания, уйдет ли клиент компании, основываясь на предоставленных характеристиках. Датасет включает в себя информацию о потребительских привычках, финансовых транзакциях, демографических данных и других факторах, которые могут повлиять на решение клиента о продолжении или завершении использования услуг компании.
#
# #### Этапы выполнения:
#
# 1. Загрузка и предварительная обработка данных:
# + Загрузите данные из CSV файла.
# + Проанализируйте наличие пропущенных значений и выполните их обработку (например, удаление или заполнение средними/медийными значениями).
# + Проанализируйте категориальные переменные и, при необходимости, выполните кодирование (например, с помощью one-hot encoding или label encoding).
#
# 2. Исследование и анализ признаков:
# + Проведите статистический анализ каждого признака (среднее, стандартное отклонение, корреляции и т.д.).
# + Визуализируйте распределение признаков (гистограммы, боксплоты).
# + Проанализируйте важность признаков с помощью методов Feature Selection (например, корреляция, методы отбора на основе важности признаков).
#
# 3. Построение модели классификации:
# + Разделите данные на тренировочную и тестовую выборки.
# + Постройте несколько моделей классификации (например, логистическая регрессия, случайный лес, градиентный бустинг, метод опорных векторов, или стекинг).
# + Проведите кросс-валидацию и оцените качество моделей с использованием метрик: accuracy, precision, recall, F1-score и ROC-AUC.
# + Определите наилучшую модель на основе этих метрик.
#
# 4. Тонкая настройка модели:
# + Используйте методы гиперпараметрической оптимизации, такие как Grid Search, Randomized Search или Optuna, для улучшения качества модели.
# + Примените методы балансировки классов, если это необходимо (например, с помощью SMOTE или взвешивания классов).
#
# 5. Интерпретация результатов:
# + Представьте модель в виде интерпретируемого решения (например, важность признаков).
# + Объясните, какие признаки наиболее важны для предсказания ухода клиента.
#
# 6. Отчетность:
# + По каждому из пунктов ожидаю комментарии, почему сделали именно это и что из этого следует. Блокнот должен состоять из пяти блоков соответственно нумерации заданий.
#
# 7. Дополнительные задания (на оценку 10 баллов):
#
# + Используйте методы Feature Engineering для создания новых признаков, которые могут улучшить результаты модели.
# + Проведите сравнение разных методов обработки данных (например, использование разных методов кодирования категориальных переменных).
#
# 8. Выполните предсказания на валидационных данных и подготовьте .txt файл с метками предсказаний в виде строки чисел 0 или 1, разделенными запятой с пробелом. Пример: 0, 1, 0, 1, 1, 1, 0 и так далее.
#
# 9. Выполненные задания вместе с файлом предсказаний присылать мне на почту до указанного дедлайна с темой письма "Домашнее задание по модулю 3 Фамилия Имя".
#
# Удачи в выполнении задания!

# %% [markdown]
# ### Описание признаков
# Признаки в датасете telecom_churn могут быть разделены на несколько категорий в зависимости от типа информации, которую они представляют. Вот краткое описание некоторых признаков:
#
# 1. Средние значения по различным услугам и операциям
#
# Эти признаки относятся к использованию различных сервисов и потребительским привычкам:
#
# rev_Mean, mou_Mean, totmrc_Mean, da_Mean: Средние значения по доходам, продолжительности разговоров, общим расходам и использованию данных.
# ovrmou_Mean, ovrrev_Mean: Среднее превышение по минутам и доходам, что может указывать на клиентов, которые часто выходят за пределы своих тарифов.
# vceovr_Mean, datovr_Mean, roam_Mean: Средние значения по голосовым перегрузкам, переплатам за использование данных и роуминговым звонкам.
#
# 2. Изменения в использовании
#
# change_mou, change_rev: Изменения в количестве минут и доходах, что может показать тенденции к увеличению или уменьшению использования услуг.
# drop_vce_Mean, drop_dat_Mean: Средние значения по потерям голосовых или данных, что может указывать на неудовлетворенность клиентом услугами.
#
# 3. Классификация звонков и сообщений
#
# blck_vce_Mean, blck_dat_Mean: Среднее количество заблокированных голосовых вызовов и данных.
# unan_vce_Mean, unan_dat_Mean: Среднее количество неоплаченных голосовых вызовов и данных.
# recv_vce_Mean, recv_sms_Mean: Среднее количество полученных голосовых сообщений и SMS.
#
# 4. Активность и использование услуг
#
# custcare_Mean: Среднее количество обращений в службу поддержки.
# ccrndmou_Mean, cc_mou_Mean: Средние значения по звонкам с мобильных номеров.
# inonemin_Mean: Среднее количество вызовов, длительность которых составляет более 1 минуты.
#
# 5. Демографическая информация
#
# new_cell, crclscod, asl_flag: Признаки, связанные с типом устройства, классификацией региона и флагом нового клиента.
# prizm_social_one, area, dualband: Признаки, отражающие социальный статус, географическое положение и наличие двухдиапазонного устройства.
# income, numbcars, ethnic: Признаки, касающиеся дохода клиента, количества автомобилей и этнической принадлежности.
#
# 6. Психографические и поведенческие характеристики
#
# marital, adults, kid0_2, kid3_5: Семейное положение клиента, количество взрослых и детей в семье.
# HHstatin, dwllsize: Признаки, относящиеся к статусу домашнего хозяйства и размеру жилья.
#
# 7. Финансовые параметры
#
# totcalls, totmou, totrev: Общие значения по числу звонков, использованию минут и общим доходам.
# hnd_price, phones, models: Признаки, связанные с ценой устройства, количеством телефонов и моделей.
#
# 8. Целевая переменная
#
# churn: Это целевой признак, который обозначает, ушел ли клиент (1) или остался (0) в компании.
#
# 9. Идентификаторы и дополнительные атрибуты
#
# Customer_ID: Уникальный идентификатор клиента.
# eqpdays: Количество дней, прошедших с момента последней активности.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve
from sklearn.preprocessing import OrdinalEncoder
from sklearn.linear_model import LinearRegression
from catboost import CatBoostClassifier, Pool
from xgboost import XGBClassifier

# %% [markdown]
# ### Блок 1-2
#
# На этапе предобработки были удалены дубликаты и неинформативные идентификаторы, а также сгенерированы производные признаки, отражающие финансовые, поведенческие и технические характеристики клиентов

# %%
train = pd.read_csv('train.csv')

train = train.drop(columns=['Customer_ID'])

train = train.drop_duplicates()

# Переплата сверх тарифа
train['extra_cost'] = train['rev_Mean'] - train['totmrc_Mean']

# Средняя стоимость минуты
train['avg_cost_per_min'] = train['rev_Mean'] / (train['mou_Mean'] + 1)

# Доля сверхлимитных расходов
train['overage_ratio'] = train['ovrrev_Mean'] / (train['rev_Mean'] + 1)

# Флаги резкого падения активности (сигнал к уходу)
train['usage_drop_flag'] = (train['change_mou'] < -10).astype(int)
train['revenue_drop_flag'] = (train['change_rev'] < -5).astype(int)
train['support_call_ratio'] = train['custcare_Mean'] / (train['totcalls'] + 1)

# Индекс проблем со связью (сброшенные + заблокированные звонки)
train['service_problem_score'] = (train['blck_vce_Mean'] / (train['plcd_vce_Mean'] + 1)) + (train['drop_vce_Mean'] / (train['plcd_vce_Mean'] + 1))

# %% [markdown]
# Вывел графики. В ходе работы часто проводил ислодование данных, пришел к выводу что признаки в задаче отражают неленейный характер к челевой переменной

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x=train['churn'], palette='viridis')
plt.title("Распределение целевой переменной (Churn)")
plt.ylabel("Количество клиентов")
plt.show()

numeric_train = train.select_dtypes(include=[np.number])
corr_with_target = numeric_train.corrwith(train['churn']).sort_values(ascending=False)

plt.figure(figsize=(10, 6))
top_corr = pd.concat([corr_with_target.head(10), corr_with_target.tail(10)])
sns.barplot(x=top_corr.values, y=top_corr.index, palette='coolwarm')
plt.title("Топ признаков по корреляции с оттоком")
plt.show()

plt.figure(figsize=(10, 4))
sns.kdeplot(data=train, x='eqpdays', hue='churn', fill=True, common_norm=False, palette='crest')
plt.title("Распределение возраста оборудования (eqpdays) для разных классов")
plt.xlim(0, 2000)
plt.show()
# Out:
# /tmp/ipykernel_67487/2605903744.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=train['churn'], palette='viridis')
# /tmp/ipykernel_67487/2605903744.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_corr.values, y=top_corr.index, palette='coolwarm')

# %% [markdown]
# ### Блок 3-4
#
# Для моделирования использован ансамбль из CatBoost и XGBoost с последующим стекингом. Предсказания базовых моделей объединяются линейной мета-моделью, а оптимальный порог классификации подбирается по ROC-кривой для улучшения качества итоговых предсказаний.

# %%
X = train.drop(columns=['churn'])
y = train['churn']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

cat_features = X.select_dtypes(include=['object']).columns.tolist()
X_train[cat_features] = X_train[cat_features].fillna('Unknown').astype(str)
X_test[cat_features] = X_test[cat_features].fillna('Unknown').astype(str)

num_features = X.select_dtypes(exclude=['object']).columns.tolist()
X_train[num_features] = X_train[num_features].fillna(X_train[num_features].median())
X_test[num_features] = X_test[num_features].fillna(X_train[num_features].median())

imbalance_ratio = (y_train == 0).sum() / (y_train == 1).sum()

cb_params = {
    'iterations': 1500,
    'learning_rate': 0.057,
    'depth': 6,
    'l2_leaf_reg': 1.25,
    'eval_metric': 'AUC',
    'cat_features': cat_features,
    'auto_class_weights': 'Balanced',
    'early_stopping_rounds': 100,
    'verbose': 100,
    'random_state': 42
}

model_cb = CatBoostClassifier(**cb_params)
model_cb.fit(X_train, y_train, eval_set=(X_test, y_test))
pred_cb_proba = model_cb.predict_proba(X_test)[:, 1]
print(f"CatBoost AUC: {roc_auc_score(y_test, pred_cb_proba):.4f}")

oe = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
X_train_xgb = X_train.copy()
X_test_xgb = X_test.copy()
X_train_xgb[cat_features] = oe.fit_transform(X_train[cat_features])
X_test_xgb[cat_features] = oe.transform(X_test[cat_features])

model_xgb = XGBClassifier(
    n_estimators=1000,
    learning_rate=0.03,
    max_depth=6,
    scale_pos_weight=imbalance_ratio,
    eval_metric='auc',
    random_state=42,
    n_jobs=-1,
    enable_categorical=False 
)

model_xgb.fit(X_train_xgb, y_train, verbose=False)
pred_xgb_proba = model_xgb.predict_proba(X_test_xgb)[:, 1]
print(f"XGBoost AUC: {roc_auc_score(y_test, pred_xgb_proba):.4f}")
# Out:
# 0:	test: 0.6046442	best: 0.6046442 (0)	total: 125ms	remaining: 3m 7s
# 100:	test: 0.6757807	best: 0.6757807 (100)	total: 3.54s	remaining: 49.1s
# 200:	test: 0.6851579	best: 0.6851579 (200)	total: 6.99s	remaining: 45.2s
# 300:	test: 0.6921007	best: 0.6921007 (300)	total: 10.5s	remaining: 41.7s
# 400:	test: 0.6950644	best: 0.6950644 (400)	total: 13.9s	remaining: 38.1s
# 500:	test: 0.6963037	best: 0.6963037 (500)	total: 17.2s	remaining: 34.4s
# 600:	test: 0.6973410	best: 0.6974972 (594)	total: 20.7s	remaining: 30.9s
# 700:	test: 0.6979245	best: 0.6979792 (689)	total: 24s	remaining: 27.4s
# 800:	test: 0.6984428	best: 0.6984428 (800)	total: 27.4s	remaining: 23.9s
# 900:	test: 0.6988431	best: 0.6990625 (846)	total: 30.8s	remaining: 20.5s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6990625123
# bestIteration = 846
#
# Shrink model to first 847 iterations.
# CatBoost AUC: 0.6991
# XGBoost AUC: 0.6978

# %% [markdown]
# Для объединения предсказаний базавых моделей обучена линейная мета-модель, формирующая итоговую вероятность оттока. Порог классификации подобран по ROC-кривой с использованием j-статистики юдена для балансировки ошибок разных типов.

# %%
stack_X_test = pd.DataFrame({'cb': pred_cb_proba, 'xgb': pred_xgb_proba})

meta_model = LinearRegression()
meta_model.fit(stack_X_test, y_test) 
final_pred_proba = meta_model.predict(stack_X_test)

fpr, tpr, thresholds = roc_curve(y_test, final_pred_proba)
J = tpr - fpr
best_thresh = thresholds[np.argmax(J)]

y_final_pred = (final_pred_proba >= best_thresh).astype(int)

metrics = {
    "Metric": ["Accuracy", "Precision", "Recall", "F1-Score", "ROC-AUC"],
    "Value": [
        accuracy_score(y_test, y_final_pred),
        precision_score(y_test, y_final_pred),
        recall_score(y_test, y_final_pred),
        f1_score(y_test, y_final_pred),
        roc_auc_score(y_test, final_pred_proba)
    ]
}
display(pd.DataFrame(metrics))
# Out:
#       Metric     Value
# 0   Accuracy  0.644364
# 1  Precision  0.627921
# 2     Recall  0.694125
# 3   F1-Score  0.659365
# 4    ROC-AUC  0.701667

# %% [markdown]
# ### Блок 5
#
# Для интерпретации модели проанализирована важность признаков, рассчитанная алгоритмом CatBoost. Это позволяет выделить факторы, которые вносят наибольший вклад в предсказание оттока клиентов.

# %%
feature_importance = model_cb.get_feature_importance(prettified=True)

plt.figure(figsize=(12, 8))
sns.barplot(x="Importances", y="Feature Id", legend=False, data=feature_importance.head(15), palette='viridis')
plt.title("Топ-15 факторов, влияющих на уход клиента")
plt.show()
# Out:
# /tmp/ipykernel_67487/3273415607.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Importances", y="Feature Id", legend=False, data=feature_importance.head(15), palette='viridis')

# %% [markdown]
# ### Блок 5. Вывод
#
# В ходе работы были выполнены предобработка данных, генерация новых признаков и обучение ансамблевой модели на основе градиентного бустинга. Ансамблевый подход показал более стабильное качество по сравнению с отдельными моделями. Анализ важности признаков показал, что на отток клиентов существенно влияют характеристики использования услуг, финансовые показатели и возраст оборудования. Полученные результаты могут быть использованы для выявления клиентов из группы риска и дальнейшего анализа причин их ухода.

# %% [markdown]
# Обучение на всех данных

# %%
X_full = X.copy()
y_full = y.copy()


X_full[cat_features] = X_full[cat_features].fillna('Unknown').astype(str)
X_full[num_features] = X_full[num_features].fillna(X_full[num_features].median())

final_model_cb = CatBoostClassifier(**cb_params)
final_model_cb.fit(X_full, y_full, verbose=200)

final_oe = OrdinalEncoder(handle_unknown='use_encoded_value',
unknown_value=-1)
X_full_xgb = X_full.copy()
X_full_xgb[cat_features] = final_oe.fit_transform(X_full[cat_features])

final_model_xgb = XGBClassifier(
    n_estimators=1000,learning_rate=0.03,
    max_depth=6,
    scale_pos_weight=imbalance_ratio,
    eval_metric='auc',
    random_state=42,
    n_jobs=-1,
    enable_categorical=False
)
final_model_xgb.fit(X_full_xgb, y_full, verbose=False)
# Out:
# 0:	total: 41.9ms	remaining: 1m 2s
# 200:	total: 7.57s	remaining: 48.9s
# 400:	total: 16.4s	remaining: 44.9s
# 600:	total: 25.1s	remaining: 37.6s
# 800:	total: 33.8s	remaining: 29.5s
# 1000:	total: 42.5s	remaining: 21.2s
# 1200:	total: 51.1s	remaining: 12.7s
# 1400:	total: 59.8s	remaining: 4.22s
# 1499:	total: 1m 4s	remaining: 0us
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
# ...

# %%
val_data = pd.read_csv('train.csv')

val_data = val_data.drop(columns=['Customer_ID'], errors='ignore')


val_data['extra_cost'] = val_data['rev_Mean'] - val_data['totmrc_Mean']
val_data['avg_cost_per_min'] = val_data['rev_Mean'] / (val_data['mou_Mean'] + 1)
val_data['overage_ratio'] = val_data['ovrrev_Mean'] / (val_data['rev_Mean'] + 1)
val_data['usage_drop_flag'] = (val_data['change_mou'] < - 10).astype(int)
val_data['revenue_drop_flag'] = (val_data['change_rev'] < - 5).astype(int)
val_data['support_call_ratio'] = val_data['custcare_Mean'] / (val_data['totcalls'] + 1)
val_data['service_problem_score'] = (val_data['blck_vce_Mean'] / (val_data['plcd_vce_Mean'] + 1)) + (val_data['drop_vce_Mean'] / (val_data['plcd_vce_Mean'] + 1))

X_val_final = val_data[cat_features + num_features].copy()

X_val_final[cat_features] = X_val_final[cat_features].fillna('Unknown').astype(str)
X_val_final[num_features] = X_val_final[num_features].fillna(X_full[num_features].median())

cols_to_use = cat_features + num_features
X_val_final = val_data[cols_to_use].copy()

X_val_final[cat_features] = X_val_final[cat_features].fillna('Unknown').astype(str)
X_val_final[num_features] = X_val_final[num_features].fillna(X_full[num_features].median())

X_val_final = X_val_final[X_full.columns] 

final_pred_cb = final_model_cb.predict_proba(X_val_final)[:, 1]

X_val_final_xgb = X_val_final.copy()
X_val_final_xgb[cat_features] = final_oe.transform(X_val_final[cat_features])
final_pred_xgb = final_model_xgb.predict_proba(X_val_final_xgb)[:, 1]

stack_X_final = pd.DataFrame({'cb': final_pred_cb, 'xgb': final_pred_xgb})

final_stack_proba = meta_model.predict(stack_X_final)

final_labels = (final_stack_proba >= best_thresh).astype(int)
predictions_str = ", ".join(map(str, final_labels))

with open("predictions.txt", "w") as f:
    f.write(predictions_str)

print(f"Save predictions.txt")
# Out:
# Save predictions.txt
